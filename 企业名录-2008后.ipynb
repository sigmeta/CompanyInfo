# %%
import requests  
import os
import re
import time
import json
import random
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
from pandas import DataFrame

# %%
agentpool=[
    "Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US) AppleWebKit/523.15 (KHTML, like Gecko, Safari/419.3)  Arora/0.3 (Change: 287 c9dfb30)",
    "Mozilla/5.0 (X11; U; Linux; en-US) AppleWebKit/523.15 (KHTML, like Gecko, Safari/419.3)  Arora/0.2 (Change: 0 )",
    "Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.1; .NET CLR 1.1.4322; FDM)",
    "Mozilla/4.0 (compatible; MSIE 6.0; Windows NT 5.0; Avant Browser [avantbrowser.com]; Hotbar 4.4.5.0)",
    "Amiga-AWeb/3.5.07 beta",
    "Mozilla/6.0; (Spoofed by Amiga-AWeb/3.5.07 beta)",
    "Mozilla/5.0 (Macintosh; U; PPC Mac OS X 10.4; en; rv:1.9.0.19) Gecko/2011091218 Camino/2.0.9 (like Firefox/3.0.19)",
    "Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10.6; en; rv:1.9.0.19) Gecko/2011032020 Camino/2.0.7 (like Firefox/3.0.19)",
    "Mozilla/5.0 (Macintosh; U; Intel Mac OS X; en; rv:1.8.1.14) Gecko/20080409 Camino/1.6 (like Firefox/2.0.0.14)",
    "Mozilla/5.0 (Windows NT 6.0) AppleWebKit/535.7 (KHTML, like Gecko) Chrome/16.0.912.63 Safari/535.7",
    "Mozilla/5.0 (Windows NT 5.1) AppleWebKit/535.2 (KHTML, like Gecko) Chrome/15.0.874.121 Safari/535.2",
    "Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/535.1 (KHTML, like Gecko) Chrome/14.0.835.202 Safari/535.1",
    "Mozilla/5.0 (Windows NT 6.0; WOW64) AppleWebKit/535.1 (KHTML, like Gecko) Chrome/14.0.835.186 Safari/535.1",
    "Mozilla/5.0 (Windows NT 6.0; WOW64) AppleWebKit/535.1 (KHTML, like Gecko) Chrome/14.0.835.126 Safari/535.1",
    "Mozilla/5.0 (X11; U; OpenBSD i386; en-US; rv:1.8.1.14) Gecko/20080821 Firefox/2.0.0.14",
    "Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.7.13) Gecko/20060410 Firefox/1.0.8",
    "Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.7.3) Gecko/20041002 Firefox/0.10.1",
    "Mozilla/5.0 (X11; U; SunOS sun4m; en-US; rv:1.4b) Gecko/20030517 Mozilla Firebird/0.6",
    "Mozilla/5.0 (Windows; U; WinNT4.0; en-US; rv:1.3a) Gecko/20021207 Phoenix/0.5",
    "Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.2b) Gecko/20020923 Phoenix/0.1",
    "Mozilla/5.0 (X11; U; Linux i686; en-US; rv:1.9.0.3) Gecko/2008100716 Firefox/3.0.3 Flock/2.0",
    "Mozilla/5.0 (X11; U; Linux i686; en-US; rv:1.8.0.4) Gecko/20060612 Firefox/1.5.0.4 Flock/0.7.0.17.1",
    "Mozilla/5.0 (Windows; U; Windows NT 5.1; en-US; rv:1.8b5) Gecko/20051019 Flock/0.4 Firefox/1.0+",
    "Mozilla/5.0 (X11; U; OpenBSD i386; en-US; rv:1.8.1.19) Gecko/20090701 Galeon/2.0.7",
    "Mozilla/5.0 (Windows; Windows i686) KHTML/4.8.0 (like Gecko) Konqueror/4.8",
    "Mozilla/5.0 (compatible; Konqueror/4.0; Microsoft Windows) KHTML/4.0.80 (like Gecko)",
    "Mozilla/5.0 (compatible; Konqueror/4.0; Linux) KHTML/4.0.5 (like Gecko)",
    "Mozilla/5.0 (compatible; Konqueror/4.0; Microsoft Windows) KHTML/4.0.80 (like Gecko)",
    "Mozilla/5.0 (compatible; Konqueror/3.5; GNU/kFreeBSD) KHTML/3.5.9 (like Gecko) (Debian)",
    "Mozilla/5.0 (compatible; Konqueror/3.5; Darwin)  KHTML/3.5.6 (like Gecko)",
    "Mozilla/5.0 (compatible; Konqueror/3.5; Linux; X11; x86_64) KHTML/3.5.6 (like Gecko) (Kubuntu)",
    "Mozilla/5.0 (compatible; Konqueror/3.4; GNU/kFreeBSD) KHTML/3.4.2 (like Gecko) (Debian package 4:3.4.2-4)",
    "Mozilla/5.0 (compatible; Konqueror/3.4; CYGWIN_NT-5.1) KHTML/3.4.89 (like Gecko)",
    "Mozilla/5.0 (X11; U; Linux i686; en-US; rv:1.9.1.9) Gecko/20100508 SeaMonkey/2.0.4",
    "Mozilla/5.0 (X11; U; Linux i686; nb-NO; rv:1.9.1.8) Gecko/20100205 SeaMonkey/2.0.3",
    "Mozilla/5.0 (X11; U; Linux i686; en-US; rv:1.9.1b4pre) Gecko/20090405 SeaMonkey/2.0b1pre",
    "Mozilla/5.0 (X11; U; Linux i686; en-US; rv:1.9.1b1pre) Gecko/20080915000512 SeaMonkey/2.0a1pre",
    "Mozilla/5.0 (X11; U; Linux i686; en-US; rv:1.9pre) Gecko/2008060901 SeaMonkey/2.0a1pre",
    "Mozilla/5.0 (X11; U; Linux i686; en-US; rv:1.8.1.13) Gecko/20080313 SeaMonkey/1.1.9 (Ubuntu-1.1.9+nobinonly-0ubuntu1)",
    "Mozilla/5.0 (X11; U; SunOS sun4u; en-US; rv:1.7) Gecko/20070606",
    "Mozilla/5.0 (X11; U; Linux i686; en-US; rv:1.7.8) Gecko/20050927 Debian/1.7.8-1sarge3",
    "Mozilla/5.0 (X11; U; Linux i686; en-US; rv:1.8.1b2) Gecko/20060823 SeaMonkey/1.1a",
    "Mozilla/5.0 (X11; U; Linux i686; en-US; rv:1.7.13) Gecko/20060417",
]

# %%
df=DataFrame([],columns=['company','province','gdxx'])

# %%
url='https://pucha2008.mingluji.com/beijing/dnb?page=106'
headers={'User-Agent':random.choice(agentpool)}
res=requests.get(url,headers=headers)
#res.encoding='utf-8'
soup=BeautifulSoup(res.text,'lxml')

# %%
soup.find_all('td', class_="views-field views-field-title")[0].text
# Out:
# '\n北京燕盛隆汽车维修有限公司 '

# %%
url='https://pucha2008.mingluji.com/'
headers={'User-Agent':random.choice(agentpool)}
res=requests.get(url,headers=headers)
#res.encoding='utf-8'
soup=BeautifulSoup(res.text,'lxml')

#plist=[t.a['href'] for t in soup.find_all('td', class_="views-field views-field-field-province")]
#allnum=[int(t.text.strip()) for t in soup.find_all('td', class_="views-field views-field-field-quantity")]
plist2=[t.td.text for t in soup.find('div',class_="field-item even").table.find_all('tr')[1:]]
rawnum=[t.td.next_sibling.text for t in soup.find('div',class_="field-item even").table.find_all('tr')[1:]]
print(plist2)
print(rawnum)
# Out:
# ['安徽', '北京', '重庆', '福建', '甘肃', '广东', '广西', '贵州', '海南', '河北', '黑龙江', '河南', '湖北', '湖南', '江苏', '江西', '吉林', '辽宁', '内蒙古', '宁夏', '青海', '陕西', '山东', '上海', '山西', '四川', '天津', '新疆', '西藏', '云南', '浙江']
# ['(160,429)', '(261,282)', '(115,171)', '(187,713)', '(56,403)', '(562,713)', '(111,600)', '(58,942)', '(23,438)', '(202,710)', '(117,451)', '(270,128)', '(230,766)', '(173,523)', '(582,170)', '(103,391)', '(97,430)', '(275,539)', '(83,644)', '(18,505)', '(13,338)', '(126,985)', '(479,796)', '(348,127)', '(108,985)', '(205,876)', '(135,858)', '(57,154)', '(4,247)', '(84,527)', '(488,957)']

# %%
allnum=[]
for x in rawnum:
    allnum.append(int(re.sub('\(|,|\)','',x)))
print(allnum)
# Out:
# [160429, 261282, 115171, 187713, 56403, 562713, 111600, 58942, 23438, 202710, 117451, 270128, 230766, 173523, 582170, 103391, 97430, 275539, 83644, 18505, 13338, 126985, 479796, 348127, 108985, 205876, 135858, 57154, 4247, 84527, 488957]

# %%
c=0
for a in allnum:
    c+=a
print(c)
# Out:
# 5746798

# %%
plist=['/anhui', '/beijing', '/chongqing', '/fujian', '/gansu', '/guangdong', '/guangxi', '/guizhou', '/hainan', '/hebei',
       '/heilongjiang', '/henan', '/hubei', '/hunan', '/jiangsu', '/jiangxi', '/jilin', '/liaoning', '/neimenggu', '/ningxia',
# %%
#2008前
for p in range(6,16):
    print(plist[p],p)
    file="E:/Py/com/minglu/b"+plist[p]+".txt"
    page_num=20000
    for page in range(0,page_num):#page_num+1
        print('page:',page,p)
        #time.sleep(random.uniform(1,3))
        url='https://pucha2008.mingluji.com'+plist[p]+'/dnb?page='+str(page)
        proxies={'http':'http://'+random.choice(ippool)}
        try:
            headers={'User-Agent':random.choice(agentpool)}
            res=requests.get(url,headers=headers,proxies=proxies,timeout=10)
        except:
            print('重新尝试')
            time.sleep(5)
            headers={'User-Agent':random.choice(agentpool)}
            proxies={'http':'http://'+random.choice(ippool)}
            res=requests.get(url,headers=headers,proxies=proxies,timeout=20)
        soup=BeautifulSoup(res.text,'lxml')
        if not soup.find('td', class_="views-field views-field-title"):
            break
        tlist=soup.find_all('td', class_="views-field views-field-title")
        with open(file,'a',encoding='utf-8') as f:
            for t in tlist:
                f.write(t.text.strip()+'\n')
        #print('n:',n,'p:',p)
            #n+=1
print('完成！')

# %%
#2008后
for p in range(,15):
    print(plist[p],p)
    file="E:/Py/com/minglu/b"+plist[p]+".txt"
    page_num=allnum[p]//100
    for page in range(0,1):#page_num+1
        print('page:',page,page_num)
        #time.sleep(random.uniform(1,3))
        url='https://gongshang.mingluji.com'+plist[p]+'/list?page='+str(page)
        proxies={'http':'http://'+random.choice(ippool)}
        try:
            headers={'User-Agent':random.choice(agentpool)}
            res=requests.get(url,headers=headers,proxies=proxies,timeout=10)
        except:
            print('重新尝试')
            time.sleep(5)
            headers={'User-Agent':random.choice(agentpool)}
            proxies={'http':'http://'+random.choice(ippool)}
            res=requests.get(url,headers=headers,proxies=proxies,timeout=20)
        soup=BeautifulSoup(res.text,'lxml')
        tlist=soup.find_all('span', class_="field-content")
        with open(file,'a',encoding='utf-8') as f:
            for t in tlist:
                f.write(t.text+'\n')
        #print('n:',n,'p:',p)
            #n+=1
print('完成！')
# Out:
# /guangdong 12
# page: 0 13421
# /guangxi 13
# page: 0 1028
# /hainan 14
# page: 0 329
# /henan 15
# page: 0 4616
# /hubei 16
# page: 0 3343
# /hunan 17
# page: 0 4254
# /heilongjiang 18
# page: 0 1650
# /jilin 19
# page: 0 1228
# /liaoning 20
# page: 0 2811
# /shaanxi 21
# page: 0 1943
# /gansu 22
# page: 0 1065
# /ningxia 23
# page: 0 251
# /qinghai 24
# page: 0 271
# /xinjiang 25
# page: 0 409
# /chongqing 26
# page: 0 2122
# /sichuan 27
# page: 0 3200
# /yunnan 28
# page: 0 1954
# /guizhou 29
# page: 0 906
# /xizang 30
# page: 0 193
# 完成！

# %%
df
# Out:
#                        company   province gdxx
# 0                     慈溪市赞莹电器厂  /zhejiang
# 1                   杭州五朋纺织有限公司  /zhejiang
# 2               宁波高新区百瑞纺织品有限公司  /zhejiang
# 3                宁波高新区创联贸易有限公司  /zhejiang
# 4              宁波高新区山外山大酒店有限公司  /zhejiang
# 5              宁波高新区视科网络开发有限公司  /zhejiang
# 6        宁波高新区天威诚信数字证书技术服务有限公司  /zhejiang
# 7        宁波高新区怡洋三维边坡绿化技术开发有限公司  /zhejiang
# 8              宁波高新区元昊投资发展有限公司  /zhejiang
# 9              宁波市北仑得胜文具制造有限公司  /zhejiang
# 10                  宁波市镇海豪佳塑料厂  /zhejiang
# 11                   宁波市镇海依木超市  /zhejiang
# 12              宁海县梅林街道能永模具加工厂  /zhejiang
# 13                上虞市百官街道坤轮家俱厂  /zhejiang
# 14              绍兴县平水镇梅园村经济合作社  /zhejiang
# 15                台州市椒绿果业专业合作社  /zhejiang
# 16                 温州市双运鞋材有限公司  /zhejiang
# 17                      象山大和药房  /zhejiang
# 18                  象山光丽电器有限公司  /zhejiang
# 19                     象山侨荣轻机厂  /zhejiang
# 20                  象山县西周恒福模具厂  /zhejiang
# 21                  象山县西周宏红塑料厂  /zhejiang
# 22                   象山兴土汽车配件厂  /zhejiang
# 23                永康市石柱晟阳五金机械厂  /zhejiang
# 24                         胡媛媛  /zhejiang
# 25              《商品与质量》周刊社浙江分社  /zhejiang
# 26         33252温州市鹿城区仰义胡旭红眼镜厂  /zhejiang
# 27               3Ｍ中国有限公司杭州分公司  /zhejiang
# 28            SMC（中国）有限公司绍兴营业所  /zhejiang
# 29      TCL家用电器（惠州）有限公司慈溪顺达分公司  /zhejiang
# ...                        ...        ...  ...
# 872367            天台县荣轩汽车用品经营部  /zhejiang
# 872368            天台县梓彤汽车用品经营部  /zhejiang
# 872369            天台县孝忠汽车用品经营部  /zhejiang
# 872370           天台县聚宝阁汽车用品经营部  /zhejiang
# 872371            天台县福青汽车用品经营部  /zhejiang
# 872372           温岭市城西瞿记顺昌食品商行  /zhejiang
# 872373                     陈宗正  /zhejiang
# 872374             温岭市城东雅婷童装商行  /zhejiang
# 872375              温岭市城东锦的便利店  /zhejiang
# 872376           温岭市城东大耀通讯设备商行  /zhejiang
# 872377          温岭市城东车宇汽车用品经营部  /zhejiang
# 872378                     徐明勇  /zhejiang
# 872379                     陈春富  /zhejiang
# 872380             温岭市城东宝富针织品店  /zhejiang
# 872381                     陈高鹏  /zhejiang
# 872382                     杨君飞  /zhejiang
# 872383                     黄菊英  /zhejiang
# 872384           温岭市太平尚腾酒店用品商行  /zhejiang
# 872385                     代红梅  /zhejiang
# 872386                     蔡新中  /zhejiang
# 872387                     金洪聪  /zhejiang
# 872388                     陈卫平  /zhejiang
# 872389              温岭市横峰时新广告店  /zhejiang
# 872390                      袁桓  /zhejiang
# 872391              温岭市城东天勇便利店  /zhejiang
# 872392                     骆彩云  /zhejiang
# 872393              温岭市泽国开心渔具店  /zhejiang
# 872394                     王仁中  /zhejiang
# 872395                温岭市金顶电机厂  /zhejiang
# 872396                     NaN        NaN  NaN
#
# [872397 rows x 3 columns]

# %%
df.to_csv('minglu/zhejiang.csv',index=False,encoding='utf-8')

# %%
from sqlalchemy import create_engine
engine = create_engine('mysql+pymysql://root:9432@localhost:3306/investor?charset=utf8')#用sqlalchemy创建引擎  
df.to_sql('company',engine,if_exists='append')#存入数据库

# %%
clist=df.loc[:872300,'company'].tolist()

# %%
with open('E:/Py/com/minglu/zhejiang.txt','a',encoding='utf-8') as f:
    for c in clist:
        f.write(c+'\n')
